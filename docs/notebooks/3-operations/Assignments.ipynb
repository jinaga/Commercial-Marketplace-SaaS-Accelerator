// %%
#!import "../1-models/AzurePortalIntegration.ipynb"
#!import "../3-operations/Connection.ipynb"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>
// # Azure Subscription
//
// This model is based on the subscription webhooks received from the Azure Marketplace.
// The landing page creates these facts.
// The portal subscribes to them to determine how many replicators can be configured.
//
// ## Enterprise Application Pattern
//
// The Azure landing page app is an enterprise application.
// The top-level user is a temporary principal.
// It is created to initialize the environment and the first administrator.
// And then the private key is discarded.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="177pt" height="133pt"
//  viewBox="0.00 0.00 177.24 132.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 128.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-128.5 173.24,-128.5 173.24,4 -4,4"/>
// <!-- Azure.Environment -->
// <g id="node1" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="84.62" cy="-18" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="84.62" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="84.62" cy="-106.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="84.62" y="-101.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M84.62,-36.09C84.62,-47.74 84.62,-63.45 84.62,-76.98"/>
// <polygon fill="black" stroke="black" points="81.12,-76.64 84.62,-86.64 88.12,-76.64 81.12,-76.64"/>
// <text text-anchor="middle" x="105.24" y="-57.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// </g>
// </svg>
// Administrators represent people.
// Administrators are granted permission to add service principals and other administrators to an environment.
// That permission can be revoked.
//
// The creator of the environment grants permission to the initial administrator.
// Thereafter, an administrator can add new administrators and revoke permissions.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="324pt" height="310pt"
//  viewBox="0.00 0.00 324.02 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 320.02,-305.5 320.02,4 -4,4"/>
// <!-- Azure.Administrator -->
// <g id="node1" class="node">
// <title>Azure.Administrator</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-106.5" rx="88.2" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Administrator</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Administrator&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.Administrator&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M116.08,-124.88C114.33,-138.92 112.07,-159.19 111.15,-177 110.32,-192.98 110.32,-197.02 111.15,-213 111.85,-226.5 113.31,-241.41 114.74,-253.95"/>
// <polygon fill="black" stroke="black" points="111.24,-254.1 115.9,-263.61 118.19,-253.27 111.24,-254.1"/>
// <text text-anchor="middle" x="124.52" y="-189.95" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node3" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="231.4" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="231.4" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Administrator&#45;&gt;Azure.Environment -->
// <g id="edge2" class="edge">
// <title>Azure.Administrator&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M140.45,-124.38C157.56,-137.48 181.49,-155.8 200.51,-170.35"/>
// <polygon fill="black" stroke="black" points="198.13,-172.94 208.2,-176.24 202.38,-167.38 198.13,-172.94"/>
// <text text-anchor="middle" x="220.77" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge4" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M209.61,-212.68C192.19,-226.01 167.59,-244.84 148.33,-259.59"/>
// <polygon fill="black" stroke="black" points="146.37,-256.68 140.56,-265.54 150.62,-262.24 146.37,-256.68"/>
// <text text-anchor="middle" x="205.02" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.Administrator.Revoke -->
// <g id="node4" class="node">
// <title>Azure.Administrator.Revoke</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-18" rx="118.4" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Administrator.Revoke</text>
// </g>
// <!-- Azure.Administrator.Revoke&#45;&gt;Azure.Administrator -->
// <g id="edge3" class="edge">
// <title>Azure.Administrator.Revoke&#45;&gt;Azure.Administrator</title>
// <path fill="none" stroke="black" d="M118.4,-36.09C118.4,-47.74 118.4,-63.45 118.4,-76.98"/>
// <polygon fill="black" stroke="black" points="114.9,-76.64 118.4,-86.64 121.9,-76.64 114.9,-76.64"/>
// <text text-anchor="middle" x="156.65" y="-57.2" font-family="Times,serif" font-size="14.00"> administrator</text>
// </g>
// </g>
// </svg>
// ## Azure Marketplace Service Principals
//
// Service principals represents machines.
// Different machines play different roles within the process.
// The model represents each role as a different type, so that authorization and distribution rules can be granular.
//
// Azure Marketplace service principals run the marketplace admin site and landing page.
// They respond to user input, administrator input, and webhooks.
// They can record facts about user identities and subscriptions.
//
// Portal service principals run the Replicator portal.
// They connect the user and their replicators to Azure user identities and subscriptions.
// They use that information to enable and disable endpoints in the multitenant replicator and API gateway.
//
// An administrator creates service principals.
// Service principals cannot grant privileges to others.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="333pt" height="310pt"
//  viewBox="0.00 0.00 333.23 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 329.23,-305.5 329.23,4 -4,4"/>
// <!-- Azure.ServicePrincipal -->
// <g id="node1" class="node">
// <title>Azure.ServicePrincipal</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-106.5" rx="96.9" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.ServicePrincipal</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.ServicePrincipal&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.ServicePrincipal&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M125.29,-124.88C123.54,-138.92 121.29,-159.19 120.36,-177 119.53,-192.98 119.53,-197.02 120.36,-213 121.06,-226.5 122.53,-241.41 123.96,-253.95"/>
// <polygon fill="black" stroke="black" points="120.45,-254.1 125.11,-263.61 127.4,-253.27 120.45,-254.1"/>
// <text text-anchor="middle" x="133.74" y="-189.95" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node3" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="240.61" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="240.61" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.ServicePrincipal&#45;&gt;Azure.Environment -->
// <g id="edge2" class="edge">
// <title>Azure.ServicePrincipal&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M149.67,-124.38C166.78,-137.48 190.7,-155.8 209.72,-170.35"/>
// <polygon fill="black" stroke="black" points="207.34,-172.94 217.41,-176.24 211.6,-167.38 207.34,-172.94"/>
// <text text-anchor="middle" x="229.99" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge4" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M218.82,-212.68C201.41,-226.01 176.81,-244.84 157.54,-259.59"/>
// <polygon fill="black" stroke="black" points="155.58,-256.68 149.77,-265.54 159.84,-262.24 155.58,-256.68"/>
// <text text-anchor="middle" x="214.24" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.ServicePrincipal.Revoke -->
// <g id="node4" class="node">
// <title>Azure.ServicePrincipal.Revoke</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-18" rx="127.61" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.ServicePrincipal.Revoke</text>
// </g>
// <!-- Azure.ServicePrincipal.Revoke&#45;&gt;Azure.ServicePrincipal -->
// <g id="edge3" class="edge">
// <title>Azure.ServicePrincipal.Revoke&#45;&gt;Azure.ServicePrincipal</title>
// <path fill="none" stroke="black" d="M127.61,-36.09C127.61,-47.74 127.61,-63.45 127.61,-76.98"/>
// <polygon fill="black" stroke="black" points="124.11,-76.64 127.61,-86.64 131.11,-76.64 124.11,-76.64"/>
// <text text-anchor="middle" x="172.99" y="-57.2" font-family="Times,serif" font-size="14.00"> servicePrincipal</text>
// </g>
// </g>
// </svg>
// ## Subscriptions
//
// Azure informs the landing page app of subscription activities by and related to a user.
// It does so through webhook calls.
// The landing page app also permits that user to take actions on the subscription through its own user interface.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="270pt" height="310pt"
//  viewBox="0.00 0.00 270.39 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 266.39,-305.5 266.39,4 -4,4"/>
// <!-- Azure.Subscription -->
// <g id="node1" class="node">
// <title>Azure.Subscription</title>
// <ellipse fill="none" stroke="black" cx="131.19" cy="-106.5" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="131.19" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node2" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="131.19" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="131.19" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Subscription&#45;&gt;Azure.Environment -->
// <g id="edge1" class="edge">
// <title>Azure.Subscription&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M131.19,-124.59C131.19,-136.24 131.19,-151.95 131.19,-165.48"/>
// <polygon fill="black" stroke="black" points="127.69,-165.14 131.19,-175.14 134.69,-165.14 127.69,-165.14"/>
// <text text-anchor="middle" x="167.57" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node4" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="131.19" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="131.19" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge3" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M131.19,-213.09C131.19,-224.74 131.19,-240.45 131.19,-253.98"/>
// <polygon fill="black" stroke="black" points="127.69,-253.64 131.19,-263.64 134.69,-253.64 127.69,-253.64"/>
// <text text-anchor="middle" x="151.82" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.Subscription.Unsubscribe -->
// <g id="node3" class="node">
// <title>Azure.Subscription.Unsubscribe</title>
// <ellipse fill="none" stroke="black" cx="131.19" cy="-18" rx="131.19" ry="18"/>
// <text text-anchor="middle" x="131.19" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Subscription.Unsubscribe</text>
// </g>
// <!-- Azure.Subscription.Unsubscribe&#45;&gt;Azure.Subscription -->
// <g id="edge2" class="edge">
// <title>Azure.Subscription.Unsubscribe&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M131.19,-36.09C131.19,-47.74 131.19,-63.45 131.19,-76.98"/>
// <polygon fill="black" stroke="black" points="127.69,-76.64 131.19,-86.64 134.69,-76.64 127.69,-76.64"/>
// <text text-anchor="middle" x="166.07" y="-57.2" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// </g>
// </svg>
// This model also represents the user by their identifier.
// The model does not treat Azure users as Jinaga users.
// It records information _about_ the user, not _by_ the user.
//
// A user can transfer a subscription to another user.
// This is modeled using the Entity Reference pattern, a kind of mutable property.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="361pt" height="310pt"
//  viewBox="0.00 0.00 360.77 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 356.77,-305.5 356.77,4 -4,4"/>
// <!-- Azure.Subscription.UserIdentity -->
// <g id="node1" class="node">
// <title>Azure.Subscription.UserIdentity</title>
// <ellipse fill="none" stroke="black" cx="173.57" cy="-18" rx="131.19" ry="18"/>
// <text text-anchor="middle" x="173.57" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Subscription.UserIdentity</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription.UserIdentity -->
// <g id="edge3" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription.UserIdentity</title>
// <path fill="none" stroke="black" d="M293.86,-10.53C311.15,-11.73 322.77,-14.22 322.77,-18 322.77,-20.89 315.95,-23.03 305.01,-24.41"/>
// <polygon fill="black" stroke="black" points="305,-20.9 295.37,-25.32 305.66,-27.87 305,-20.9"/>
// <text text-anchor="middle" x="337.77" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- Azure.Subscription -->
// <g id="node2" class="node">
// <title>Azure.Subscription</title>
// <ellipse fill="none" stroke="black" cx="82.57" cy="-106.5" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="82.57" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription -->
// <g id="edge1" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M155.59,-36.09C142.13,-48.88 123.52,-66.57 108.46,-80.89"/>
// <polygon fill="black" stroke="black" points="106.45,-77.98 101.61,-87.4 111.27,-83.05 106.45,-77.98"/>
// <text text-anchor="middle" x="171.45" y="-57.2" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.UserIdentity -->
// <g id="node3" class="node">
// <title>Azure.UserIdentity</title>
// <ellipse fill="none" stroke="black" cx="265.57" cy="-106.5" rx="82.06" ry="18"/>
// <text text-anchor="middle" x="265.57" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.UserIdentity</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.UserIdentity -->
// <g id="edge2" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.UserIdentity</title>
// <path fill="none" stroke="black" d="M191.75,-36.09C205.45,-48.97 224.41,-66.8 239.69,-81.17"/>
// <polygon fill="black" stroke="black" points="236.96,-83.4 246.64,-87.7 241.76,-78.3 236.96,-83.4"/>
// <text text-anchor="middle" x="261.7" y="-57.2" font-family="Times,serif" font-size="14.00"> userIdentity</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node4" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="173.57" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="173.57" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Subscription&#45;&gt;Azure.Environment -->
// <g id="edge4" class="edge">
// <title>Azure.Subscription&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M100.12,-124.18C113.63,-137.02 132.5,-154.96 147.74,-169.44"/>
// <polygon fill="black" stroke="black" points="145.01,-171.68 154.67,-176.04 149.84,-166.61 145.01,-171.68"/>
// <text text-anchor="middle" x="172.95" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.UserIdentity&#45;&gt;Azure.Environment -->
// <g id="edge5" class="edge">
// <title>Azure.UserIdentity&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M248.97,-124.47C238.88,-134.64 225.66,-147.74 213.57,-159 209.82,-162.49 205.82,-166.11 201.85,-169.64"/>
// <polygon fill="black" stroke="black" points="199.65,-166.92 194.45,-176.15 204.27,-172.17 199.65,-166.92"/>
// <text text-anchor="middle" x="265.95" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node5" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="173.57" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="173.57" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge6" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M173.57,-213.09C173.57,-224.74 173.57,-240.45 173.57,-253.98"/>
// <polygon fill="black" stroke="black" points="170.07,-253.64 173.57,-263.64 177.07,-253.64 170.07,-253.64"/>
// <text text-anchor="middle" x="194.2" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// </g>
// </svg>
// ## Subscription Activities
//
// A user can adjust the plan to which a subscription applies.
// This is captured as a mutable property.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="296pt" height="310pt"
//  viewBox="0.00 0.00 295.95 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 291.95,-305.5 291.95,4 -4,4"/>
// <!-- Azure.Plan -->
// <g id="node1" class="node">
// <title>Azure.Plan</title>
// <ellipse fill="none" stroke="black" cx="52.38" cy="-106.5" rx="52.38" ry="18"/>
// <text text-anchor="middle" x="52.38" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Plan</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node2" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="128.38" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="128.38" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Plan&#45;&gt;Azure.Environment -->
// <g id="edge1" class="edge">
// <title>Azure.Plan&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M65.79,-123.93C74.22,-134.14 85.4,-147.47 95.63,-159 98.44,-162.18 101.43,-165.48 104.42,-168.72"/>
// <polygon fill="black" stroke="black" points="101.79,-171.03 111.17,-175.97 106.92,-166.27 101.79,-171.03"/>
// <text text-anchor="middle" x="131.75" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node5" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="128.38" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="128.38" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge5" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M128.38,-213.09C128.38,-224.74 128.38,-240.45 128.38,-253.98"/>
// <polygon fill="black" stroke="black" points="124.88,-253.64 128.38,-263.64 131.88,-253.64 124.88,-253.64"/>
// <text text-anchor="middle" x="149" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.SubscriptionPlan -->
// <g id="node3" class="node">
// <title>Azure.SubscriptionPlan</title>
// <ellipse fill="none" stroke="black" cx="128.38" cy="-18" rx="98.95" ry="18"/>
// <text text-anchor="middle" x="128.38" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.SubscriptionPlan</text>
// </g>
// <!-- Azure.SubscriptionPlan&#45;&gt;Azure.Plan -->
// <g id="edge3" class="edge">
// <title>Azure.SubscriptionPlan&#45;&gt;Azure.Plan</title>
// <path fill="none" stroke="black" d="M113.36,-36.09C102.25,-48.73 86.95,-66.14 74.46,-80.37"/>
// <polygon fill="black" stroke="black" points="72.07,-77.78 68.1,-87.6 77.33,-82.4 72.07,-77.78"/>
// <text text-anchor="middle" x="109.88" y="-57.2" font-family="Times,serif" font-size="14.00"> plan</text>
// </g>
// <!-- Azure.SubscriptionPlan&#45;&gt;Azure.SubscriptionPlan -->
// <g id="edge4" class="edge">
// <title>Azure.SubscriptionPlan&#45;&gt;Azure.SubscriptionPlan</title>
// <path fill="none" stroke="black" d="M218.6,-10.22C234.36,-11.26 245.32,-13.85 245.32,-18 245.32,-21.05 239.41,-23.25 230.03,-24.62"/>
// <polygon fill="black" stroke="black" points="229.7,-21.14 220.11,-25.63 230.41,-28.1 229.7,-21.14"/>
// <text text-anchor="middle" x="260.32" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- Azure.Subscription -->
// <g id="node4" class="node">
// <title>Azure.Subscription</title>
// <ellipse fill="none" stroke="black" cx="205.38" cy="-106.5" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="205.38" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription</text>
// </g>
// <!-- Azure.SubscriptionPlan&#45;&gt;Azure.Subscription -->
// <g id="edge2" class="edge">
// <title>Azure.SubscriptionPlan&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M143.59,-36.09C154.77,-48.65 170.14,-65.92 182.76,-80.09"/>
// <polygon fill="black" stroke="black" points="179.92,-82.17 189.19,-87.32 185.15,-77.52 179.92,-82.17"/>
// <text text-anchor="middle" x="208.25" y="-57.2" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.Subscription&#45;&gt;Azure.Environment -->
// <g id="edge6" class="edge">
// <title>Azure.Subscription&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M194.62,-124.47C187.68,-134.89 178.15,-148.24 168.38,-159 165,-162.71 161.26,-166.42 157.46,-169.97"/>
// <polygon fill="black" stroke="black" points="155.4,-167.12 150.28,-176.39 160.06,-172.33 155.4,-167.12"/>
// <text text-anchor="middle" x="217.75" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// </g>
// </svg>
// The user can activate and deactivate their subscription.
// Azure can also choose to suspend and reinstate the subscription.
// Finally, the user periodically renews their subscription.
// Renewal occurs within a monthly period.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="742pt" height="398pt"
//  viewBox="0.00 0.00 742.14 398.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 394)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-394 738.14,-394 738.14,4 -4,4"/>
// <!-- Azure.Subscription.Suspend -->
// <g id="node1" class="node">
// <title>Azure.Subscription.Suspend</title>
// <ellipse fill="none" stroke="black" cx="609.72" cy="-106.5" rx="116.35" ry="18"/>
// <text text-anchor="middle" x="609.72" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription.Suspend</text>
// </g>
// <!-- Azure.Subscription -->
// <g id="node2" class="node">
// <title>Azure.Subscription</title>
// <ellipse fill="none" stroke="black" cx="344.72" cy="-195" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="344.72" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Subscription</text>
// </g>
// <!-- Azure.Subscription.Suspend&#45;&gt;Azure.Subscription -->
// <g id="edge1" class="edge">
// <title>Azure.Subscription.Suspend&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M561.42,-123.26C515.86,-138.14 447.61,-160.42 399.91,-175.99"/>
// <polygon fill="black" stroke="black" points="399.02,-172.59 390.6,-179.02 401.19,-179.25 399.02,-172.59"/>
// <text text-anchor="middle" x="535.6" y="-145.7" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node8" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="253.72" cy="-283.5" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="253.72" y="-278.45" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Subscription&#45;&gt;Azure.Environment -->
// <g id="edge7" class="edge">
// <title>Azure.Subscription&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M329.31,-213.18C319.89,-223.43 307.43,-236.53 295.72,-247.5 291.77,-251.2 287.5,-254.98 283.24,-258.64"/>
// <polygon fill="black" stroke="black" points="281.2,-255.78 275.8,-264.9 285.7,-261.14 281.2,-255.78"/>
// <text text-anchor="middle" x="348.1" y="-234.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Subscription.Reinstate -->
// <g id="node3" class="node">
// <title>Azure.Subscription.Reinstate</title>
// <ellipse fill="none" stroke="black" cx="614.72" cy="-18" rx="119.42" ry="18"/>
// <text text-anchor="middle" x="614.72" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Subscription.Reinstate</text>
// </g>
// <!-- Azure.Subscription.Reinstate&#45;&gt;Azure.Subscription.Suspend -->
// <g id="edge2" class="edge">
// <title>Azure.Subscription.Reinstate&#45;&gt;Azure.Subscription.Suspend</title>
// <path fill="none" stroke="black" d="M613.73,-36.09C613.06,-47.74 612.15,-63.45 611.37,-76.98"/>
// <polygon fill="black" stroke="black" points="607.89,-76.45 610.81,-86.64 614.88,-76.86 607.89,-76.45"/>
// <text text-anchor="middle" x="635.35" y="-57.2" font-family="Times,serif" font-size="14.00"> suspend</text>
// </g>
// <!-- Azure.Subscription.Renew -->
// <g id="node4" class="node">
// <title>Azure.Subscription.Renew</title>
// <ellipse fill="none" stroke="black" cx="110.72" cy="-106.5" rx="110.72" ry="18"/>
// <text text-anchor="middle" x="110.72" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription.Renew</text>
// </g>
// <!-- Azure.Subscription.Renew&#45;&gt;Azure.Subscription -->
// <g id="edge3" class="edge">
// <title>Azure.Subscription.Renew&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M153.91,-123.47C193.31,-138.03 251.58,-159.57 293.35,-175.01"/>
// <polygon fill="black" stroke="black" points="292.12,-178.29 302.71,-178.47 294.54,-171.72 292.12,-178.29"/>
// <text text-anchor="middle" x="283.6" y="-145.7" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.Month -->
// <g id="node5" class="node">
// <title>Azure.Month</title>
// <ellipse fill="none" stroke="black" cx="172.72" cy="-195" rx="61.08" ry="18"/>
// <text text-anchor="middle" x="172.72" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Month</text>
// </g>
// <!-- Azure.Subscription.Renew&#45;&gt;Azure.Month -->
// <g id="edge4" class="edge">
// <title>Azure.Subscription.Renew&#45;&gt;Azure.Month</title>
// <path fill="none" stroke="black" d="M122.97,-124.59C131.8,-136.91 143.89,-153.77 153.93,-167.79"/>
// <polygon fill="black" stroke="black" points="150.95,-169.63 159.62,-175.72 156.63,-165.55 150.95,-169.63"/>
// <text text-anchor="middle" x="167.22" y="-145.7" font-family="Times,serif" font-size="14.00"> month</text>
// </g>
// <!-- Azure.Month&#45;&gt;Azure.Environment -->
// <g id="edge8" class="edge">
// <title>Azure.Month&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M188.34,-212.68C200.25,-225.4 216.85,-243.13 230.35,-257.54"/>
// <polygon fill="black" stroke="black" points="227.45,-259.57 236.84,-264.47 232.56,-254.78 227.45,-259.57"/>
// <text text-anchor="middle" x="257.1" y="-234.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Subscription.Activate -->
// <g id="node6" class="node">
// <title>Azure.Subscription.Activate</title>
// <ellipse fill="none" stroke="black" cx="355.72" cy="-106.5" rx="116.35" ry="18"/>
// <text text-anchor="middle" x="355.72" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription.Activate</text>
// </g>
// <!-- Azure.Subscription.Activate&#45;&gt;Azure.Subscription -->
// <g id="edge5" class="edge">
// <title>Azure.Subscription.Activate&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M353.55,-124.59C352.07,-136.24 350.07,-151.95 348.35,-165.48"/>
// <polygon fill="black" stroke="black" points="344.91,-164.79 347.12,-175.15 351.85,-165.67 344.91,-164.79"/>
// <text text-anchor="middle" x="385.6" y="-145.7" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.Subscription.Deactivate -->
// <g id="node7" class="node">
// <title>Azure.Subscription.Deactivate</title>
// <ellipse fill="none" stroke="black" cx="352.72" cy="-18" rx="124.54" ry="18"/>
// <text text-anchor="middle" x="352.72" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Subscription.Deactivate</text>
// </g>
// <!-- Azure.Subscription.Deactivate&#45;&gt;Azure.Subscription.Activate -->
// <g id="edge6" class="edge">
// <title>Azure.Subscription.Deactivate&#45;&gt;Azure.Subscription.Activate</title>
// <path fill="none" stroke="black" d="M353.31,-36.09C353.72,-47.74 354.26,-63.45 354.73,-76.98"/>
// <polygon fill="black" stroke="black" points="351.22,-76.76 355.07,-86.64 358.22,-76.52 351.22,-76.76"/>
// <text text-anchor="middle" x="376.6" y="-57.2" font-family="Times,serif" font-size="14.00"> activate</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node9" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="253.72" cy="-372" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="253.72" y="-366.95" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge9" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M253.72,-301.59C253.72,-313.24 253.72,-328.95 253.72,-342.48"/>
// <polygon fill="black" stroke="black" points="250.22,-342.14 253.72,-352.14 257.22,-342.14 250.22,-342.14"/>
// <text text-anchor="middle" x="274.35" y="-322.7" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// </g>
// </svg>
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>
// ## Replicator
//
// A developer can create any number of replicators.
// They give them a name and an environment (typically "dev", "test", or "prod").
// Both name and environment are mutable properties.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="780pt" height="221pt"
//  viewBox="0.00 0.00 779.90 221.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 217)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-217 775.9,-217 775.9,4 -4,4"/>
// <!-- RaaS.Replicator -->
// <g id="node1" class="node">
// <title>RaaS.Replicator</title>
// <ellipse fill="none" stroke="black" cx="379.88" cy="-106.5" rx="71.31" ry="18"/>
// <text text-anchor="middle" x="379.88" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Replicator</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="379.88" cy="-195" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="379.88" y="-189.95" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- RaaS.Replicator&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>RaaS.Replicator&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M379.88,-124.59C379.88,-136.24 379.88,-151.95 379.88,-165.48"/>
// <polygon fill="black" stroke="black" points="376.38,-165.14 379.88,-175.14 383.38,-165.14 376.38,-165.14"/>
// <text text-anchor="middle" x="393" y="-145.7" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- RaaS.Replicator.Name -->
// <g id="node3" class="node">
// <title>RaaS.Replicator.Name</title>
// <ellipse fill="none" stroke="black" cx="95.88" cy="-18" rx="95.88" ry="18"/>
// <text text-anchor="middle" x="95.88" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.Name</text>
// </g>
// <!-- RaaS.Replicator.Name&#45;&gt;RaaS.Replicator -->
// <g id="edge2" class="edge">
// <title>RaaS.Replicator.Name&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M144.7,-33.87C194.89,-49.16 272.89,-72.92 325.15,-88.83"/>
// <polygon fill="black" stroke="black" points="323.85,-92.09 334.44,-91.66 325.89,-85.4 323.85,-92.09"/>
// <text text-anchor="middle" x="291.63" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Replicator.Name&#45;&gt;RaaS.Replicator.Name -->
// <g id="edge3" class="edge">
// <title>RaaS.Replicator.Name&#45;&gt;RaaS.Replicator.Name</title>
// <path fill="none" stroke="black" d="M182.77,-10.16C198.63,-11.15 209.76,-13.77 209.76,-18 209.76,-21.14 203.63,-23.39 193.98,-24.75"/>
// <polygon fill="black" stroke="black" points="193.89,-21.24 184.28,-25.69 194.57,-28.21 193.89,-21.24"/>
// <text text-anchor="middle" x="224.76" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- RaaS.Replicator.Environment -->
// <g id="node4" class="node">
// <title>RaaS.Replicator.Environment</title>
// <ellipse fill="none" stroke="black" cx="379.88" cy="-18" rx="121.98" ry="18"/>
// <text text-anchor="middle" x="379.88" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.Environment</text>
// </g>
// <!-- RaaS.Replicator.Environment&#45;&gt;RaaS.Replicator -->
// <g id="edge4" class="edge">
// <title>RaaS.Replicator.Environment&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M379.88,-36.09C379.88,-47.74 379.88,-63.45 379.88,-76.98"/>
// <polygon fill="black" stroke="black" points="376.38,-76.64 379.88,-86.64 383.38,-76.64 376.38,-76.64"/>
// <text text-anchor="middle" x="407.63" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Replicator.Environment&#45;&gt;RaaS.Replicator.Environment -->
// <g id="edge5" class="edge">
// <title>RaaS.Replicator.Environment&#45;&gt;RaaS.Replicator.Environment</title>
// <path fill="none" stroke="black" d="M491.62,-10.45C508.45,-11.62 519.86,-14.13 519.86,-18 519.86,-20.93 513.31,-23.09 502.81,-24.46"/>
// <polygon fill="black" stroke="black" points="502.75,-20.95 493.13,-25.4 503.42,-27.92 502.75,-20.95"/>
// <text text-anchor="middle" x="534.86" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- RaaS.Replicator.Deleted -->
// <g id="node5" class="node">
// <title>RaaS.Replicator.Deleted</title>
// <ellipse fill="none" stroke="black" cx="669.88" cy="-18" rx="102.02" ry="18"/>
// <text text-anchor="middle" x="669.88" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.Deleted</text>
// </g>
// <!-- RaaS.Replicator.Deleted&#45;&gt;RaaS.Replicator -->
// <g id="edge6" class="edge">
// <title>RaaS.Replicator.Deleted&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M619.36,-34.07C568.01,-49.39 488.63,-73.06 435.5,-88.91"/>
// <polygon fill="black" stroke="black" points="434.62,-85.52 426.04,-91.73 436.62,-92.23 434.62,-85.52"/>
// <text text-anchor="middle" x="577.63" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// </g>
// </svg>
// ## Authentication
//
// A developer can configure authentication mechanisms for replicators.
// Supported authentication mechanisms include Apple and Google.
// Given the requirements of each of those providers, these authentication mechanisms take different parameters.
//
// While the end user authenticates with Apple or Google, they use that identity to further authenticate with the replicator.
// This phase is a standard OAuth2 authorization code flow.
// The developer supplies callback URLs for this flow.
//
// All of this configuration information is shared with an environment.
// This environment is well known to the developer.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="1171pt" height="221pt"
//  viewBox="0.00 0.00 1171.09 221.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 217)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-217 1167.09,-217 1167.09,4 -4,4"/>
// <!-- RaaS.Environment -->
// <g id="node1" class="node">
// <title>RaaS.Environment</title>
// <ellipse fill="none" stroke="black" cx="616.45" cy="-106.5" rx="81.55" ry="18"/>
// <text text-anchor="middle" x="616.45" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="529.45" cy="-195" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="529.45" y="-189.95" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- RaaS.Environment&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>RaaS.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M599.67,-124.18C586.71,-137.06 568.58,-155.09 553.99,-169.6"/>
// <polygon fill="black" stroke="black" points="551.57,-167.07 546.95,-176.6 556.51,-172.03 551.57,-167.07"/>
// <text text-anchor="middle" x="601.07" y="-145.7" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationServiceRequest -->
// <g id="node3" class="node">
// <title>RaaS.Replicator.AuthenticationServiceRequest</title>
// <ellipse fill="none" stroke="black" cx="185.45" cy="-18" rx="185.45" ry="18"/>
// <text text-anchor="middle" x="185.45" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.AuthenticationServiceRequest</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Environment -->
// <g id="edge2" class="edge">
// <title>RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Environment</title>
// <path fill="none" stroke="black" d="M334.26,-29.01C399.9,-34.77 468.99,-43.06 499.45,-54 512.06,-58.53 512.75,-64.41 524.7,-70.5 536.44,-76.49 549.47,-82.06 561.92,-86.91"/>
// <polygon fill="black" stroke="black" points="560.67,-90.18 571.26,-90.44 563.15,-83.63 560.67,-90.18"/>
// <text text-anchor="middle" x="560.82" y="-57.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Replicator.AuthenticationServiceRequest -->
// <g id="edge4" class="edge">
// <title>RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Replicator.AuthenticationServiceRequest</title>
// <path fill="none" stroke="black" d="M357.62,-11.02C376.62,-12.35 388.89,-14.67 388.89,-18 388.89,-20.6 381.4,-22.59 369.06,-23.97"/>
// <polygon fill="black" stroke="black" points="368.78,-20.48 359.12,-24.85 369.39,-27.45 368.78,-20.48"/>
// <text text-anchor="middle" x="403.89" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- RaaS.Replicator -->
// <g id="node4" class="node">
// <title>RaaS.Replicator</title>
// <ellipse fill="none" stroke="black" cx="444.45" cy="-106.5" rx="71.31" ry="18"/>
// <text text-anchor="middle" x="444.45" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Replicator</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Replicator -->
// <g id="edge3" class="edge">
// <title>RaaS.Replicator.AuthenticationServiceRequest&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M235.69,-35.78C280.67,-50.8 346.39,-72.75 392.02,-87.99"/>
// <polygon fill="black" stroke="black" points="390.85,-91.29 401.44,-91.14 393.07,-84.65 390.85,-91.29"/>
// <text text-anchor="middle" x="366.2" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Replicator&#45;&gt;Jinaga.User -->
// <g id="edge11" class="edge">
// <title>RaaS.Replicator&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M460.83,-124.18C473.42,-136.98 490.98,-154.86 505.19,-169.32"/>
// <polygon fill="black" stroke="black" points="502.54,-171.61 512.05,-176.29 507.53,-166.71 502.54,-171.61"/>
// <text text-anchor="middle" x="507.57" y="-145.7" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationApple -->
// <g id="node5" class="node">
// <title>RaaS.Replicator.AuthenticationApple</title>
// <ellipse fill="none" stroke="black" cx="964.45" cy="-18" rx="150.64" ry="18"/>
// <text text-anchor="middle" x="964.45" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.AuthenticationApple</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Environment -->
// <g id="edge5" class="edge">
// <title>RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Environment</title>
// <path fill="none" stroke="black" d="M939.57,-36.12C921.48,-47.71 895.96,-62.35 871.45,-70.5 818.63,-88.06 756.85,-96.82 707.33,-101.19"/>
// <polygon fill="black" stroke="black" points="707.17,-97.69 697.5,-102 707.75,-104.66 707.17,-97.69"/>
// <text text-anchor="middle" x="944.82" y="-57.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Replicator -->
// <g id="edge6" class="edge">
// <title>RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M890.13,-34.04C833.61,-45.13 753.85,-60.05 683.45,-70.5 613.53,-80.88 595.22,-77.23 525.45,-88.5 519.59,-89.45 513.53,-90.53 507.46,-91.68"/>
// <polygon fill="black" stroke="black" points="507.22,-88.16 498.08,-93.52 508.57,-95.03 507.22,-88.16"/>
// <text text-anchor="middle" x="804.2" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Replicator.AuthenticationApple -->
// <g id="edge7" class="edge">
// <title>RaaS.Replicator.AuthenticationApple&#45;&gt;RaaS.Replicator.AuthenticationApple</title>
// <path fill="none" stroke="black" d="M1103.38,-10.73C1121.27,-11.99 1133.09,-14.41 1133.09,-18 1133.09,-20.77 1126.02,-22.85 1114.54,-24.24"/>
// <polygon fill="black" stroke="black" points="1114.52,-20.72 1104.89,-25.13 1115.17,-27.69 1114.52,-20.72"/>
// <text text-anchor="middle" x="1148.09" y="-12.95" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationGoogle -->
// <g id="node6" class="node">
// <title>RaaS.Replicator.AuthenticationGoogle</title>
// <ellipse fill="none" stroke="black" cx="592.45" cy="-18" rx="155.25" ry="18"/>
// <text text-anchor="middle" x="592.45" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.AuthenticationGoogle</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Environment -->
// <g id="edge8" class="edge">
// <title>RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Environment</title>
// <path fill="none" stroke="black" d="M597.19,-36.09C600.45,-47.86 604.87,-63.77 608.65,-77.39"/>
// <polygon fill="black" stroke="black" points="605.18,-77.99 611.23,-86.69 611.93,-76.12 605.18,-77.99"/>
// <text text-anchor="middle" x="642.82" y="-57.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Replicator -->
// <g id="edge9" class="edge">
// <title>RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M495.04,-32.36C471.67,-37.63 451.3,-44.71 443.95,-54 438.81,-60.48 437.45,-69 437.81,-77.23"/>
// <polygon fill="black" stroke="black" points="434.31,-77.47 439.05,-86.94 441.26,-76.58 434.31,-77.47"/>
// <text text-anchor="middle" x="472.2" y="-57.2" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Replicator.AuthenticationGoogle -->
// <g id="edge10" class="edge">
// <title>RaaS.Replicator.AuthenticationGoogle&#45;&gt;RaaS.Replicator.AuthenticationGoogle</title>
// <path fill="none" stroke="black" d="M735.51,-10
// ## RaaS Portal Administrators
//
// Administrators represent people who can configure an environment.
// They grant privileges to other administrators and to service principals.
// That permission can be revoked.
//
// The creator of the environment grants permission to the first administrator.
// Thereafter, an administrator can add new administrators and revoke privileges.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="315pt" height="310pt"
//  viewBox="0.00 0.00 314.88 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 310.88,-305.5 310.88,4 -4,4"/>
// <!-- RaaS.Administrator -->
// <g id="node1" class="node">
// <title>RaaS.Administrator</title>
// <ellipse fill="none" stroke="black" cx="115.33" cy="-106.5" rx="85.13" ry="18"/>
// <text text-anchor="middle" x="115.33" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Administrator</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="115.33" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="115.33" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- RaaS.Administrator&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>RaaS.Administrator&#45;&gt;Jinaga.User</title>
// ...
// <title>RaaS.Replicator.AuthenticationApple</title>
// <ellipse fill="none" stroke="black" cx="151.15" cy="-106.5" rx="150.64" ry="18"/>
// <text text-anchor="middle" x
// ## Secrets
//
// When setting up authorization and distribution rules, the developer must provide a shared secret.
// They request a secret from the environment.
// A service principal responds with a randomly generated secret that can be used to authenticate a CI/CD server.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="349pt" height="310pt"
//  viewBox="0.00 0.00 348.62 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 344.62,-305.5 344.62,4 -4,4"/>
// <!-- RaaS.Replicator.SecretRequest -->
// <g id="node1" class="node">
// <title>RaaS.Replicator.SecretRequest</title>
// <ellipse fill="none" stroke="black" cx="166.55" cy="-106.5" rx="126.08" ry="18"/>
// <text text-anchor="middle" x="166.55" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Replicator.SecretRequest</text>
// </g>
// <!-- RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Replicator.SecretRequest -->
// <g id="edge3" class="edge">
// <title>RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Replicator.SecretRequest</title>
// <path fill="none" stroke="black" d="M282.14,-98.99C299.14,-100.17 310.62,-102.68 310.62,-106.5 310.62,-109.4 304.03,-111.54 293.44,-112.92"/>
// <polygon fill="black" stroke="black" points="293.26,-109.42 283.65,-113.86 293.94,-116.38 293.26,-109.42"/>
// <text text-anchor="middle" x="325.62" y="-101.45" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- RaaS.Environment -->
// <g id="node2" class="node">
// <title>RaaS.Environment</title>
// <ellipse fill="none" stroke="black" cx="81.55" cy="-195" rx="81.55" ry="18"/>
// <text text-anchor="middle" x="81.55" y="-189.95" font-family="Times,serif" font-size="14.00">RaaS.Environment</text>
// </g>
// <!-- RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Environment -->
// <g id="edge1" class="edge">
// <title>RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Environment</title>
// <path fill="none" stroke="black" d="M149.75,-124.59C137.3,-137.27 120.12,-154.75 106.12,-168.99"/>
// <polygon fill="black" stroke="black" points="103.88,-166.28 99.37,-175.87 108.87,-171.19 103.88,-166.28"/>
// <text text-anchor="middle" x="168.92" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- RaaS.Replicator -->
// <g id="node3" class="node">
// <title>RaaS.Replicator</title>
// <ellipse fill="none" stroke="black" cx="252.55" cy="-195" rx="71.31" ry="18"/>
// <text text-anchor="middle" x="252.55" y="-189.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator</text>
// </g>
// <!-- RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Replicator -->
// <g id="edge2" class="edge">
// <title>RaaS.Replicator.SecretRequest&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M189.12,-124.53C195.92,-130.01 203.25,-136.28 209.55,-142.5 217.58,-150.43 225.7,-159.74 232.68,-168.25"/>
// <polygon fill="black" stroke="black" points="229.82,-170.27 238.81,-175.88 235.28,-165.89 229.82,-170.27"/>
// <text text-anchor="middle" x="252.3" y="-145.7" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node5" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="166.55" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="166.55" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- RaaS.Environment&#45;&gt;Jinaga.User -->
// <g id="edge5" class="edge">
// <title>RaaS.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M98.34,-213.09C110.96,-225.93 128.42,-243.7 142.52,-258.05"/>
// <polygon fill="black" stroke="black" points="139.8,-260.27 149.31,-264.95 144.79,-255.37 139.8,-260.27"/>
// <text text-anchor="middle" x="153.17" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- RaaS.Replicator&#45;&gt;Jinaga.User -->
// <g id="edge6" class="edge">
// <title>RaaS.Replicator&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M235.97,-212.68C223.24,-225.48 205.46,-243.36 191.09,-257.82"/>
// <polygon fill="black" stroke="black" points="188.71,-255.24 184.15,-264.8 193.68,-260.18 188.71,-255.24"/>
// <text text-anchor="middle" x="229.67" y="-234.2" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- RaaS.Replicator.Secret -->
// <g id="node4" class="node">
// <title>RaaS.Replicator.Secret</title>
// <ellipse fill="none" stroke="black" cx="166.55" cy="-18" rx="96.39" ry="18"/>
// <text text-anchor="middle" x="166.55" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator.Secret</text>
// </g>
// <!-- RaaS.Replicator.Secret&#45;&gt;RaaS.Replicator.SecretRequest -->
// <g id="edge4" class="edge">
// <title>RaaS.Replicator.Secret&#45;&gt;RaaS.Replicator.SecretRequest</title>
// <path fill="none" stroke="black" d="M166.55,-36.09C166.55,-47.74 166.55,-63.45 166.55,-76.98"/>
// <polygon fill="black" stroke="black" points="163.05,-76.64 166.55,-86.64 170.05,-76.64 163.05,-76.64"/>
// <text text-anchor="middle" x="187.92" y="-57.2" font-family="Times,serif" font-size="14.00"> request</text>
// </g>
// </g>
// </svg>
// ## Subscription Allocation
//
// The RaaS service principal controls the connection between the Azure Marketplace and the replicator-as-a-service portal.
// The connection starts with the user identity.
// The service principal associate a Jinaga user to an Azure user identity.
// This happens on login.
//
// Then, the user requests an allocation between a replicator and a subscription.
// The service principal completes that allocation if the subscription is available.
// A replicator will only be activated if a subscription is allocated.
// If the subscription is cancelled, then the replicator is deactivated.
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="969pt" height="418pt"
//  viewBox="0.00 0.00 969.02 417.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 413.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-413.5 965.02,-413.5 965.02,4 -4,4"/>
// <!-- RaaS.UserIdentity -->
// <g id="node1" class="node">
// <title>RaaS.UserIdentity</title>
// <ellipse fill="none" stroke="black" cx="78.99" cy="-106.5" rx="78.99" ry="18"/>
// <text text-anchor="middle" x="78.99" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.UserIdentity</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="449.99" cy="-391.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="449.99" y="-386.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- RaaS.UserIdentity&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>RaaS.UserIdentity&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M83.19,-124.91C89.14,-147 101.61,-185.51 121.99,-213 167.33,-274.17 188.62,-283.68 254.99,-321 300.09,-346.36 356.13,-365.17 396.55,-376.79"/>
// <polygon fill="black" stroke="black" points="395.48,-380.12 406.06,-379.46 397.38,-373.38 395.48,-380.12"/>
// <text text-anchor="middle" x="183.11" y="-243.95" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- Azure.UserIdentity -->
// <g id="node3" class="node">
// <title>Azure.UserIdentity</title>
// <ellipse fill="none" stroke="black" cx="212.99" cy="-195" rx="82.06" ry="18"/>
// <text text-anchor="middle" x="212.99" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.UserIdentity</text>
// </g>
// <!-- RaaS.UserIdentity&#45;&gt;Azure.UserIdentity -->
// <g id="edge2" class="edge">
// <title>RaaS.UserIdentity&#45;&gt;Azure.UserIdentity</title>
// <path fill="none" stroke="black" d="M104.51,-123.97C125.37,-137.44 155.08,-156.62 178.14,-171.5"/>
// <polygon fill="black" stroke="black" points="175.99,-174.28 186.29,-176.77 179.79,-168.4 175.99,-174.28"/>
// <text text-anchor="middle" x="193.11" y="-145.7" font-family="Times,serif" font-size="14.00"> userIdentity</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node11" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="348.99" cy="-303" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="348.99" y="-297.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.UserIdentity&#45;&gt;Azure.Environment -->
// <g id="edge11" class="edge">
// <title>Azure.UserIdentity&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M221.29,-213.35C229.66,-229.23 243.95,-252.4 262.24,-267 270.35,-273.48 279.81,-278.9 289.45,-283.39"/>
// <polygon fill="black" stroke="black" points="287.96,-286.56 298.53,-287.31 290.73,-280.13 287.96,-286.56"/>
// <text text-anchor="middle" x="298.36" y="-243.95" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Subscription.UserIdentity -->
// <g id="node4" class="node">
// <title>Azure.Subscription.UserIdentity</title>
// <ellipse fill="none" stroke="black" cx="306.99" cy="-106.5" rx="131.19" ry="18"/>
// <text text-anchor="middle" x="306.99" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Subscription.UserIdentity</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.UserIdentity -->
// <g id="edge4" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.UserIdentity</title>
// <path fill="none" stroke="black" d="M270.96,-124.24C262.12,-129.34 253.09,-135.48 245.74,-142.5 238.43,-149.47 232.03,-158.38 226.87,-166.83"/>
// <polygon fill="black" stroke="black" points="223.88,-165 221.96,-175.42 229.96,-168.47 223.88,-165"/>
// <text text-anchor="middle" x="279.11" y="-145.7" font-family="Times,serif" font-size="14.00"> userIdentity</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription.UserIdentity -->
// <g id="edge5" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription.UserIdentity</title>
// <path fill="none" stroke="black" d="M427.28,-99.03C444.56,-100.23 456.18,-102.72 456.18,-106.5 456.18,-109.39 449.37,-111.53 438.42,-112.91"/>
// <polygon fill="black" stroke="black" points="438.41,-109.4 428.79,-113.82 439.07,-116.37 438.41,-109.4"/>
// <text text-anchor="middle" x="471.18" y="-101.45" font-family="Times,serif" font-size="14.00"> prior</text>
// </g>
// <!-- Azure.Subscription -->
// <g id="node5" class="node">
// <title>Azure.Subscription</title>
// <ellipse fill="none" stroke="black" cx="395.99" cy="-195" rx="82.57" ry="18"/>
// <text text-anchor="middle" x="395.99" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Subscription</text>
// </g>
// <!-- Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription -->
// <g id="edge3" class="edge">
// <title>Azure.Subscription.UserIdentity&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M311.29,-124.92C314.68,-135.77 320.36,-149.43 329.24,-159 334.32,-164.48 340.46,-169.25 346.92,-173.37"/>
// <polygon fill="black" stroke="black" points="344.83,-176.2 355.24,-178.17 348.33,-170.14 344.83,-176.2"/>
// <text text-anchor="middle" x="363.86" y="-145.7" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- Azure.Subscription&#45;&gt;Azure.Environment -->
// <g id="edge12" class="edge">
// <title>Azure.Subscription&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M362.92,-211.95C355.83,-217 349.27,-223.32 345.24,-231 338.49,-243.85 338.73,-259.87 340.97,-273.44"/>
// <polygon fill="black" stroke="black" points="337.52,-274.05 343,-283.11 344.37,-272.6 337.52,-274.05"/>
// <text text-anchor="middle" x="381.36" y="-243.95" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- RaaS.Replicator.Subscription.Request -->
// <g id="node6" class="node">
// <title>RaaS.Replicator.Subscription.Request</title>
// <ellipse fill="none" stroke="black" cx="655.99" cy="-106.5" rx="152.18" ry="18"/>
// <text text-anchor="middle" x="655.99" y="-101.45" font-family="Times,serif" font-size="14.00">RaaS.Replicator.Subscription.Request</text>
// </g>
// <!-- RaaS.Replicator.Subscription.Request&#45;&gt;Azure.Subscription -->
// <g id="edge7" class="edge">
// <title>RaaS.Replicator.Subscription.Request&#45;&gt;Azure.Subscription</title>
// <path fill="none" stroke="black" d="M543.61,-119.01C516.88,-124.17 488.95,-131.66 464.24,-142.5 449.07,-149.15 434.17,-159.79 422.17,-169.67"/>
// <polygon fill="black" stroke="black" points="420.08,-166.86 414.76,-176.02 424.63,-172.17 420.08,-166.86"/>
// <text text-anchor="middle" x="498.86" y="-145.7" font-family="Times,serif" font-size="14.00"> subscription</text>
// </g>
// <!-- RaaS.Replicator -->
// <g id="node7" class="node">
// <title>RaaS.Replicator</title>
// <ellipse fill="none" stroke="black" cx="497.99" cy="-249" rx="71.31" ry="18"/>
// <text text-anchor="middle" x="497.99" y="-243.95" font-family="Times,serif" font-size="14.00">RaaS.Replicator</text>
// </g>
// <!-- RaaS.Replicator.Subscription.Request&#45;&gt;RaaS.Replicator -->
// <g id="edge6" class="edge">
// <title>RaaS.Replicator.Subscription.Request&#45;&gt;RaaS.Replicator</title>
// <path fill="none" stroke="black" d="M623.38,-124.41C614.32,-129.71 604.72,-135.9 596.49,-142.5 566.59,-166.47 537.26,-199.45 518.49,-222.12"/>
// <polygon fill="black" stroke="black" points="515.93,-219.72 512.32,-229.68 521.35,-224.15 515.93,-219.72"/>
// <text text-anchor="middle" x="623.74" y="-145.7" font-family="Times,serif" font-size="14.00"> replicator</text>
// </g>
// <!-- RaaS.Environment -->
// <g id="node8" class="node">
// <title>RaaS.Environment</title>
// <ellipse fill="none" stroke="black" cx="655.99" cy="-249" rx="81.55" ry="18"/>
// <text text-anchor="middle" x="655.99" y="-243.95" font-family="Times,serif" font-size="14.00">RaaS.Environment</text>
// </g>
// <!-- R
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.1</span></li><li><span>Jinaga.Graphviz, 0.12.1</span></li><li><span>Jinaga.UnitTest, 0.12.1</span></li></ul></div></div>
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>(Jinaga.User, Jinaga.UserProfile)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Item1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.User</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>publicKey</td><td><div class="dni-plaintext"><pre>-----BEGIN PUBLIC KEY-----
// MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAu5WfisRF9xNpi6P7CoWH
// 57EeQrcDLlm2N69L+XBGZh/UG6k4tzHyQKUZsJxXQk4J5MsXNPN2REK0EV1MIQjO
// gEGsYVDJiiATSnEbf3x3rX/WoLc1beByoU1yr3/kTT62jokShAPhnB3EjjGQaPtU
// tAh4TZrF0xOOgRqe7C1UOBVJVezUGjrKxoG7atkcvPCBazZpai0VcshqBQnESre3
// gpp2fNLzyeivrv/DrxLj8GqGoV35BqANgu1LAh+1KknJPCPdbAZvIriklAxU6R20
// sBeuat1p8zfBk6L+L1b/SMbfXKp0RKMPTPO8I6RATudn6KNjzqXW3gEiwG4VKD3S
// 5wIDAQAB
// -----END PUBLIC KEY-----
// </pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Item2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.UserProfile</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>DisplayName</td><td><div class="dni-plaintext"><pre>Michael Perry</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
var azureCreator = configuration.ContainsKey("azureCreator") ?
    configuration["azureCreator"] :
    null;

var environmentIdentifier = configuration.ContainsKey("environmentIdentifier") ?
    configuration["environmentIdentifier"] :
    "test";

AzureEnvironment azureEnvironment;

if (azureCreator != null)
{
    // Use the existing environment.
    azureEnvironment = new AzureEnvironment(
        new User(azureCreator),
        environmentIdentifier
    );
}

jinagaClient.Hash(azureEnvironment)
// Out:
// Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg==

// %%
if (false)
{
    // Make the Microsoft login an Azure administrator.

    var microsoftUser = new User("-----BEGIN PUBLIC KEY-----\r\nMIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAu5WfisRF9xNpi6P7CoWH\r\n57EeQrcDLlm2N69L\u002BXBGZh/UG6k4tzHyQKUZsJxXQk4J5MsXNPN2REK0EV1MIQjO\r\ngEGsYVDJiiATSnEbf3x3rX/WoLc1beByoU1yr3/kTT62jokShAPhnB3EjjGQaPtU\r\ntAh4TZrF0xOOgRqe7C1UOBVJVezUGjrKxoG7atkcvPCBazZpai0VcshqBQnESre3\r\ngpp2fNLzyeivrv/DrxLj8GqGoV35BqANgu1LAh\u002B1KknJPCPdbAZvIriklAxU6R20\r\nsBeuat1p8zfBk6L\u002BL1b/SMbfXKp0RKMPTPO8I6RATudn6KNjzqXW3gEiwG4VKD3S\r\n5wIDAQAB\r\n-----END PUBLIC KEY-----\r\n");

    var admin = await jinagaClient.Fact(new AzureAdministrator(microsoftUser, azureEnvironment, DateTime.UtcNow));

    display(jinagaClient.RenderFacts(admin));
}

// %% [markdown]
// ## User Identity
//
// Who am I?

// %%
var userIdentityForUser = Given<User>.Match((user, facts) =>
    facts.OfType<RaasUserIdentity>(rui => rui.user == user)
);

var userIdentities = await jinagaClient.Query(userIdentityForUser, user);

jinagaClient.RenderFacts(user, userIdentities)
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="467pt" height="360pt"
//  viewBox="0.00 0.00 467.00 359.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 355.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-355.5 463,-355.5 463,4 -4,4"/>
// <!-- IzwkVQyXhV4jw8y8sCeCckRs7W8XOyL7NrbbIkjNr8Bf6G4Ikcwu4Urr1HbT1SpbqCI2J77q7aiieHoxNA1htQ== -->
// <g id="node1" class="node">
// <title>IzwkVQyXhV4jw8y8sCeCckRs7W8XOyL7NrbbIkjNr8Bf6G4Ikcwu4Urr1HbT1SpbqCI2J77q7aiieHoxNA1htQ==</title>
// <polygon fill="none" stroke="black" points="9,-115.5 9,-137.5 225,-137.5 225,-115.5 9,-115.5"/>
// <text text-anchor="start" x="85.12" y="-121.2" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// <polygon fill="none" stroke="black" points="9,-93.5 9,-115.5 71,-115.5 71,-93.5 9,-93.5"/>
// <text text-anchor="start" x="11.88" y="-99.2" font-family="Times,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="71,-93.5 71,-115.5 225,-115.5 225,-93.5 71,-93.5"/>
// <text text-anchor="start" x="73.75" y="-99.2" font-family="Times,serif" font-size="14.00">&#45;&#45;&#45;&#45;&#45;BEGIN PUBLIC KE...</text>
// <polygon fill="none" stroke="black" points="8,-92.5 8,-138.5 226,-138.5 226,-92.5 8,-92.5"/>
// </g>
// <!-- r9XvVJxA6B6tlcTTiJe0YtSWiYj+y2UvYDTvoEAzpEdYpaH2GoNnTJxPgX7pbPOloxKPXppw06UeefVWsMVIKw== -->
// <g id="node2" class="node">
// <title>r9XvVJxA6B6tlcTTiJe0YtSWiYj+y2UvYDTvoEAzpEdYpaH2GoNnTJxPgX7pbPOloxKPXppw06UeefVWsMVIKw==</title>
// <polygon fill="none" stroke="black" points="235,-325.5 235,-347.5 451,-347.5 451,-325.5 235,-325.5"/>
// <text text-anchor="start" x="311.12" y="-331.2" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// <polygon fill="none" stroke="black" points="235,-303.5 235,-325.5 297,-325.5 297,-303.5 235,-303.5"/>
// <text text-anchor="start" x="237.88" y="-309.2" font-family="Times,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="297,-303.5 297,-325.5 451,-325.5 451,-303.5 297,-303.5"/>
// <text text-anchor="start" x="299.75" y="-309.2" font-family="Times,serif" font-size="14.00">&#45;&#45;&#45;&#45;&#45;BEGIN PUBLIC KE...</text>
// </g>
// <!-- Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg== -->
// <g id="node3" class="node">
// <title>Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg==</title>
// <polygon fill="none" stroke="black" points="286,-221 286,-243 400,-243 400,-221 286,-221"/>
// <text text-anchor="start" x="289" y="-226.7" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// <polygon fill="none" stroke="black" points="286,-199 286,-221 374,-221 374,-199 286,-199"/>
// <text text-anchor="start" x="289.88" y="-204.7" font-family="Times,serif" font-size="14.00">environmentId</text>
// <polygon fill="none" stroke="black" points="374,-199 374,-221 400,-221 400,-199 374,-199"/>
// <text text-anchor="start" x="377.62" y="-204.7" font-family="Times,serif" font-size="14.00">test</text>
// </g>
// <!-- Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg==&#45;&gt;r9XvVJxA6B6tlcTTiJe0YtSWiYj+y2UvYDTvoEAzpEdYpaH2GoNnTJxPgX7pbPOloxKPXppw06UeefVWsMVIKw== -->
// <g id="edge1" class="edge">
// <title>Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg==&#45;&gt;r9XvVJxA6B6tlcTTiJe0YtSWiYj+y2UvYDTvoEAzpEdYpaH2GoNnTJxPgX7pbPOloxKPXppw06UeefVWsMVIKw==</title>
// <path fill="none" stroke="black" d="M343,-246.81C343,-259.19 343,-274.39 343,-288.06"/>
// <polygon fill="black" stroke="black" points="339.5,-288.05 343,-298.05 346.5,-288.05 339.5,-288.05"/>
// <text text-anchor="middle" x="363.62" y="-268.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g== -->
// <g id="node4" class="node">
// <title>rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g==</title>
// <polygon fill="none" stroke="black" points="260,-115.5 260,-137.5 426,-137.5 426,-115.5 260,-115.5"/>
// <text text-anchor="start" x="290.88" y="-121.2" font-family="Times,serif" font-size="14.00">Azure.UserIdentity</text>
// <polygon fill="none" stroke="black" points="260,-93.5 260,-115.5 299,-115.5 299,-93.5 260,-93.5"/>
// <text text-anchor="start" x="262.62" y="-99.2" font-family="Times,serif" font-size="14.00">userId</text>
// <polygon fill="none" stroke="black" points="299,-93.5 299,-115.5 426,-115.5 426,-93.5 299,-93.5"/>
// <text text-anchor="start" x="301.75" y="-99.2" font-family="Times,serif" font-size="14.00">me@michaelperry.net</text>
// </g>
// <!-- rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g==&#45;&gt;Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg== -->
// <g id="edge2" class="edge">
// <title>rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g==&#45;&gt;Lgb9GmG3CR1AcMhvkolV3Vt+rA+rdia6A5wAxeHwa+GsJZ/RskdEIXmYBdkz/68a9sYKI9r0UJBX4mFoRZ1stg==</title>
// <path fill="none" stroke="black" d="M343,-141.29C343,-154 343,-169.72 343,-183.76"/>
// <polygon fill="black" stroke="black" points="339.5,-183.54 343,-193.54 346.5,-183.54 339.5,-183.54"/>
// <text text-anchor="middle" x="379.38" y="-163.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ== -->
// <g id="node5" class="node">
// <title>duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ==</title>
// <polygon fill="none" stroke="black" points="131.62,-6.75 131.62,-29.25 238.38,-29.25 238.38,-6.75 131.62,-6.75"/>
// <text text-anchor="start" x="135.12" y="-12.95" font-family="Times,serif" font-size="14.00">RaaS.UserIdentity</text>
// <polygon fill="none" stroke="black" points="130.62,-5.75 130.62,-30.25 239.38,-30.25 239.38,-5.75 130.62,-5.75"/>
// </g>
// <!-- duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ==&#45;&gt;IzwkVQyXhV4jw8y8sCeCckRs7W8XOyL7NrbbIkjNr8Bf6G4Ikcwu4Urr1HbT1SpbqCI2J77q7aiieHoxNA1htQ== -->
// <g id="edge3" class="edge">
// <title>duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ==&#45;&gt;IzwkVQyXhV4jw8y8sCeCckRs7W8XOyL7NrbbIkjNr8Bf6G4Ikcwu4Urr1HbT1SpbqCI2J77q7aiieHoxNA1htQ==</title>
// <path fill="none" stroke="black" d="M173.16,-35.63C164.52,-47.76 152.51,-64.63 141.81,-79.65"/>
// <polygon fill="black" stroke="black" points="139.19,-77.3 136.24,-87.48 144.89,-81.36 139.19,-77.3"/>
// <text text-anchor="middle" x="172.12" y="-57.2" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ==&#45;&gt;rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g== -->
// <g id="edge4" class="edge">
// <title>duWsmxcB5aNvuVFuVVqh5gr1EPXedlOBmXVJ/gDUOMckFnfvCr6Hdxheabk60ylz7rIP6Jw8WAx5VkPGlVlsyQ==&#45;&gt;rh9w9jFTQwj8qfv7g2BBYFVcD1MB7rh10aTrgJJHktuoha33I7bpP2nrifnsZPsMDE4SrhIldlDpn+azwZNc6g==</title>
// <path fill="none" stroke="black" d="M212.88,-35.85C234.72,-49.05 265.69,-67.77 291.94,-83.64"/>
// <polygon fill="black" stroke="black" points="290.08,-86.6 300.45,-88.78 293.7,-80.61 290.08,-86.6"/>
// <text text-anchor="middle" x="302.12" y="-57.2" font-family="Times,serif" font-size="14.00"> userIdentity</text>
// </g>
// </g>
// </svg>

// %% [markdown]
// What identities are available?

// %%
var userIdentitiesInEnvironment = Given<AzureEnvironment>.Match((environment, facts) =>
    facts.OfType<UserIdentity>(ui => ui.environment == environment)
    .Select(ui => ui.userId)
);

var userIdentities = await jinagaClient.Query(userIdentitiesInEnvironment, azureEnvironment);

userIdentities
// Out:
// <div class="dni-plaintext"><pre>[ me@michaelperry.net, michael@qedcode.com ]</pre></div><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// Create a new user identity.

// %%
if (false)
{
    var userIdentity = await jinagaClient.Fact(new UserIdentity(azureEnvironment, "me@michaelperry.net"));

    display(jinagaClient.RenderFacts(userIdentity));
}

// %% [markdown]
// ## Subscriptions Available
//
// List the subscriptions available to the user.

// %%
var subscriptionsForUser = Given<User>.Match((user, facts) =>
    from raasUserIdentity in facts.OfType<RaasUserIdentity>()
    where raasUserIdentity.user == user
    from subscriptionUserIdentity in facts.OfType<SubscriptionUserIdentity>()
    where subscriptionUserIdentity.userIdentity == raasUserIdentity.userIdentity &&
        !facts.Any<SubscriptionUserIdentity>(next => next.prior.Contains(subscriptionUserIdentity))
    from subscription in facts.OfType<Subscription>()
    where subscription == subscriptionUserIdentity.subscription &&
        !facts.Any<ReplicatorSubscriptionRequest>(req => req.subscription == subscription &&
            !facts.Any<ReplicatorSubscriptionReject>(rej => rej.request == req)
        ) &&
        !facts.Any<Unsubscribe>(unsub => unsub.subscription == subscription)
    select new
    {
        Subscription = subscription,
        Names = facts.OfType<SubscriptionName>(sn => sn.subscription == subscription &&
            !facts.Any<SubscriptionName>(next => next.prior.Contains(sn)))
            .Select(sn => sn.value)
    }
);

var subscriptions = await jinagaClient.Query(subscriptionsForUser, user);

subscriptions
// Out:
// <i>(empty)</i><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// ## Test Subscription
//
// Set up a subscription for the Microsoft user so that it can appear in the list.

// %%
if (false)
{
    var userIdentity = new UserIdentity(azureEnvironment, "me@michaelperry.net");

    var subscription = await jinagaClient.Fact(new Subscription(azureEnvironment, Guid.NewGuid()));
    await jinagaClient.Fact(new SubscriptionUserIdentity(subscription, userIdentity, []));
    await jinagaClient.Fact(new SubscriptionName(subscription, "Blog", []));
}
