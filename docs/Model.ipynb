// %% [markdown]
// # Azure Subscription
//
// This model is based on the subscription webhooks received from the Azure Marketplace.
// The landing page creates these facts.
// The portal subscribes to them to determine how many replicators can be configured.

// %%
// Reference the Jinaga NuGet packages
#r "nuget: Jinaga, 0.12.0"
#r "nuget: Jinaga.Graphviz, 0.12.0"
#r "nuget: Jinaga.UnitTest, 0.12.0"
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Jinaga, 0.12.0</span></li><li><span>Jinaga.Graphviz, 0.12.0</span></li><li><span>Jinaga.UnitTest, 0.12.0</span></li></ul></div></div>

// %%
using Jinaga;
using Jinaga.Graphviz;
using Jinaga.UnitTest;

using System.Net.Http.Headers;
using System.Threading.Tasks;

public class ExpressAuthenticationHandler : Jinaga.Http.IHttpAuthenticationProvider
{
    public readonly string cookie;

    public ExpressAuthenticationHandler(string cookie)
    {
        this.cookie = cookie;
    }

    public void SetRequestHeaders(HttpRequestHeaders headers)
    {
        headers.Add("Cookie", $"connect.sid={cookie}");
    }

    public Task<bool> Reauthenticate()
    {
        return Task.FromResult(false);
    }
}

// Create a Jinaga client for the portal
var jinagaClient = JinagaClient.Create(opt =>
{
    opt.HttpEndpoint = new Uri("https://app.jinaga.com/jinaga");
    opt.HttpAuthenticationProvider = new ExpressAuthenticationHandler("your cookie");
});

// %% [markdown]
// ## Enterprise Application Pattern
//
// The Azure landing page app is an enterprise application.
// The top-level user is a temporary principal.
// It is created to initialize the environment and the first administrator.
// And then the private key is discarded.

// %%
[FactType("Azure.Environment")]
public record Environment(User creator, string environmentId);

Renderer.RenderTypes(typeof(Environment))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="177pt" height="133pt"
//  viewBox="0.00 0.00 177.24 132.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 128.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-128.5 173.24,-128.5 173.24,4 -4,4"/>
// <!-- Azure.Environment -->
// <g id="node1" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="84.62" cy="-18" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="84.62" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="84.62" cy="-106.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="84.62" y="-101.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M84.62,-36.09C84.62,-47.74 84.62,-63.45 84.62,-76.98"/>
// <polygon fill="black" stroke="black" points="81.12,-76.64 84.62,-86.64 88.12,-76.64 81.12,-76.64"/>
// <text text-anchor="middle" x="105.24" y="-57.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// </g>
// </svg>

// %% [markdown]
// Administrators represent people.
// Administrators are granted permission to add service principals and other administrators to an environment.
// That permission can be revoked.
//
// The creator of the environment grants permission to the initial administrator.
// Thereafter, an administrator can add new administrators and revoke permissions.

// %%
[FactType("Azure.Administrator")]
public record Administrator(User user, Environment environment, DateTime createdAt);

[FactType("Azure.Administrator.Revoke")]
public record RevokeAdministrator(Administrator administrator);

Renderer.RenderTypes(typeof(Administrator), typeof(RevokeAdministrator))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="324pt" height="310pt"
//  viewBox="0.00 0.00 324.02 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 320.02,-305.5 320.02,4 -4,4"/>
// <!-- Azure.Administrator -->
// <g id="node1" class="node">
// <title>Azure.Administrator</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-106.5" rx="88.2" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.Administrator</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.Administrator&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.Administrator&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M116.08,-124.88C114.33,-138.92 112.07,-159.19 111.15,-177 110.32,-192.98 110.32,-197.02 111.15,-213 111.85,-226.5 113.31,-241.41 114.74,-253.95"/>
// <polygon fill="black" stroke="black" points="111.24,-254.1 115.9,-263.61 118.19,-253.27 111.24,-254.1"/>
// <text text-anchor="middle" x="124.52" y="-189.95" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node3" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="231.4" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="231.4" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.Administrator&#45;&gt;Azure.Environment -->
// <g id="edge2" class="edge">
// <title>Azure.Administrator&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M140.45,-124.38C157.56,-137.48 181.49,-155.8 200.51,-170.35"/>
// <polygon fill="black" stroke="black" points="198.13,-172.94 208.2,-176.24 202.38,-167.38 198.13,-172.94"/>
// <text text-anchor="middle" x="220.77" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge4" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M209.61,-212.68C192.19,-226.01 167.59,-244.84 148.33,-259.59"/>
// <polygon fill="black" stroke="black" points="146.37,-256.68 140.56,-265.54 150.62,-262.24 146.37,-256.68"/>
// <text text-anchor="middle" x="205.02" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.Administrator.Revoke -->
// <g id="node4" class="node">
// <title>Azure.Administrator.Revoke</title>
// <ellipse fill="none" stroke="black" cx="118.4" cy="-18" rx="118.4" ry="18"/>
// <text text-anchor="middle" x="118.4" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.Administrator.Revoke</text>
// </g>
// <!-- Azure.Administrator.Revoke&#45;&gt;Azure.Administrator -->
// <g id="edge3" class="edge">
// <title>Azure.Administrator.Revoke&#45;&gt;Azure.Administrator</title>
// <path fill="none" stroke="black" d="M118.4,-36.09C118.4,-47.74 118.4,-63.45 118.4,-76.98"/>
// <polygon fill="black" stroke="black" points="114.9,-76.64 118.4,-86.64 121.9,-76.64 114.9,-76.64"/>
// <text text-anchor="middle" x="156.65" y="-57.2" font-family="Times,serif" font-size="14.00"> administrator</text>
// </g>
// </g>
// </svg>

// %%
// Create an environment and make the logged in user an administrator.
var (user, profile) = await jinagaClient.Login();

var environment = await jinagaClient.SingleUse(async principal =>
{
    var environment = await jinagaClient.Fact(new Environment(principal, "test"));
    await jinagaClient.Fact(new Administrator(user, environment, DateTime.UtcNow));
    return environment;
});

System.Text.Json.JsonSerializer.Serialize(environment.creator.publicKey)
// Out:
// "-----BEGIN PUBLIC KEY-----\r\nMIIBCgKCAQEAoCTbrASql8xsTby30NwsizfdDVrfg\u002B8B6y/4brCoyjbGMRpQgh\u002Ba\r\niDvcbNUsafgAyeUgxqOcpXmdyeHL3A4z0KjI1Ti5Us6RADSqve7yt21WZXxpGcmr\r\nYMlxwCJ5vmaxGN4DYAmWhZI7\u002B4zZ6wBj\u002BJarM8kEOz\u002BH3RMsnp05qAoLmx9an\u002Bpg\r\nQT8X7pBc24b\u002BuS9sAHl/hboQ/Rd7ivmErbvlyZiXktj8epuETM7VVn4aPMQqezT9\r\nNCQA6kHRC49pTrv9qtGPhI6JXIODG/blMPG6WtNY\u002B7zjEOYAtKf6isq53r1d0hVa\r\nHbdDnPpLQmoqY6/xi17nMRsX3GrVdt7AgQIDAQAB\r\n-----END PUBLIC KEY-----\r\n"

// %%
string publicKey = "-----BEGIN PUBLIC KEY-----\r\nMIIBCgKCAQEAoCTbrASql8xsTby30NwsizfdDVrfg\u002B8B6y/4brCoyjbGMRpQgh\u002Ba\r\niDvcbNUsafgAyeUgxqOcpXmdyeHL3A4z0KjI1Ti5Us6RADSqve7yt21WZXxpGcmr\r\nYMlxwCJ5vmaxGN4DYAmWhZI7\u002B4zZ6wBj\u002BJarM8kEOz\u002BH3RMsnp05qAoLmx9an\u002Bpg\r\nQT8X7pBc24b\u002BuS9sAHl/hboQ/Rd7ivmErbvlyZiXktj8epuETM7VVn4aPMQqezT9\r\nNCQA6kHRC49pTrv9qtGPhI6JXIODG/blMPG6WtNY\u002B7zjEOYAtKf6isq53r1d0hVa\r\nHbdDnPpLQmoqY6/xi17nMRsX3GrVdt7AgQIDAQAB\r\n-----END PUBLIC KEY-----\r\n";

var environment = new Environment(
    new User(publicKey),
    "test"
);

// %% [markdown]
// ## Service Principals
//
// Service principals represents machines.
// They can record facts about an environment.
//
// An administrator creates service principals.
// Service principals cannot grant privileges to others.

// %%
[FactType("Azure.ServicePrincipal")]
public record ServicePrincipal(User user, Environment environment, DateTime createdAt);

[FactType("Azure.ServicePrincipal.Revoke")]
public record RevokeServicePrincipal(ServicePrincipal servicePrincipal);

Renderer.RenderTypes(typeof(ServicePrincipal), typeof(RevokeServicePrincipal))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="333pt" height="310pt"
//  viewBox="0.00 0.00 333.23 309.50" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 305.5)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-305.5 329.23,-305.5 329.23,4 -4,4"/>
// <!-- Azure.ServicePrincipal -->
// <g id="node1" class="node">
// <title>Azure.ServicePrincipal</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-106.5" rx="96.9" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-101.45" font-family="Times,serif" font-size="14.00">Azure.ServicePrincipal</text>
// </g>
// <!-- Jinaga.User -->
// <g id="node2" class="node">
// <title>Jinaga.User</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-283.5" rx="54.42" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-278.45" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// </g>
// <!-- Azure.ServicePrincipal&#45;&gt;Jinaga.User -->
// <g id="edge1" class="edge">
// <title>Azure.ServicePrincipal&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M125.29,-124.88C123.54,-138.92 121.29,-159.19 120.36,-177 119.53,-192.98 119.53,-197.02 120.36,-213 121.06,-226.5 122.53,-241.41 123.96,-253.95"/>
// <polygon fill="black" stroke="black" points="120.45,-254.1 125.11,-263.61 127.4,-253.27 120.45,-254.1"/>
// <text text-anchor="middle" x="133.74" y="-189.95" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- Azure.Environment -->
// <g id="node3" class="node">
// <title>Azure.Environment</title>
// <ellipse fill="none" stroke="black" cx="240.61" cy="-195" rx="84.62" ry="18"/>
// <text text-anchor="middle" x="240.61" y="-189.95" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// </g>
// <!-- Azure.ServicePrincipal&#45;&gt;Azure.Environment -->
// <g id="edge2" class="edge">
// <title>Azure.ServicePrincipal&#45;&gt;Azure.Environment</title>
// <path fill="none" stroke="black" d="M149.67,-124.38C166.78,-137.48 190.7,-155.8 209.72,-170.35"/>
// <polygon fill="black" stroke="black" points="207.34,-172.94 217.41,-176.24 211.6,-167.38 207.34,-172.94"/>
// <text text-anchor="middle" x="229.99" y="-145.7" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// <!-- Azure.Environment&#45;&gt;Jinaga.User -->
// <g id="edge4" class="edge">
// <title>Azure.Environment&#45;&gt;Jinaga.User</title>
// <path fill="none" stroke="black" d="M218.82,-212.68C201.41,-226.01 176.81,-244.84 157.54,-259.59"/>
// <polygon fill="black" stroke="black" points="155.58,-256.68 149.77,-265.54 159.84,-262.24 155.58,-256.68"/>
// <text text-anchor="middle" x="214.24" y="-234.2" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- Azure.ServicePrincipal.Revoke -->
// <g id="node4" class="node">
// <title>Azure.ServicePrincipal.Revoke</title>
// <ellipse fill="none" stroke="black" cx="127.61" cy="-18" rx="127.61" ry="18"/>
// <text text-anchor="middle" x="127.61" y="-12.95" font-family="Times,serif" font-size="14.00">Azure.ServicePrincipal.Revoke</text>
// </g>
// <!-- Azure.ServicePrincipal.Revoke&#45;&gt;Azure.ServicePrincipal -->
// <g id="edge3" class="edge">
// <title>Azure.ServicePrincipal.Revoke&#45;&gt;Azure.ServicePrincipal</title>
// <path fill="none" stroke="black" d="M127.61,-36.09C127.61,-47.74 127.61,-63.45 127.61,-76.98"/>
// <polygon fill="black" stroke="black" points="124.11,-76.64 127.61,-86.64 131.11,-76.64 124.11,-76.64"/>
// <text text-anchor="middle" x="172.99" y="-57.2" font-family="Times,serif" font-size="14.00"> servicePrincipal</text>
// </g>
// </g>
// </svg>

// %%
var servicePrincipal = await jinagaClient.Fact(new ServicePrincipal(
    new User("-----BEGIN PUBLIC KEY-----\r\nMIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA0mV76/G8fGfJqSaoxfU9\r\nCVyjASlWIn2n\u002BAHnI3jdLsA6Wua6tDTpwuVt4fr9kSZTmxYYJUnBN3MVx4P9K5p9\r\nobGjtT5czi5dzdeKu2vitF5m\u002BiAdtSP1TAIFKNjPQOvC\u002BJDMFTeQaMtLobCipXJZ\r\nl6hbSNflEdqFHFH8cm\u002B2/vLL/6P9nnpWviEnyYq7Pilnb7izttjiR5cAZtN2g0q3\r\nYlDuvQ02mGVEEuJQoMXnDlHbcqxKjoc9ObSdXI7QQgpxcndRjaSAJIrxN9jgSxHU\r\nLegGKiOR2962MT0lJgYJFr\u002B24latHYJ\u002BAt\u002BM2pTW9uuM38Ks3RoVHB4ABbOnhLwX\r\nrQIDAQAB\r\n-----END PUBLIC KEY-----\r\n"),
    environment,
    DateTime.UtcNow
));

servicePrincipal
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>ServicePrincipal { user = Jinaga.User, environment = Environment { creator = Jinaga.User, environmentId = test }, createdAt = 5/31/2024 4:02:18 PM }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>user</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.User</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>publicKey</td><td><div class="dni-plaintext"><pre>-----BEGIN PUBLIC KEY-----
// MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEA0mV76/G8fGfJqSaoxfU9
// CVyjASlWIn2n+AHnI3jdLsA6Wua6tDTpwuVt4fr9kSZTmxYYJUnBN3MVx4P9K5p9
// obGjtT5czi5dzdeKu2vitF5m+iAdtSP1TAIFKNjPQOvC+JDMFTeQaMtLobCipXJZ
// l6hbSNflEdqFHFH8cm+2/vLL/6P9nnpWviEnyYq7Pilnb7izttjiR5cAZtN2g0q3
// YlDuvQ02mGVEEuJQoMXnDlHbcqxKjoc9ObSdXI7QQgpxcndRjaSAJIrxN9jgSxHU
// LegGKiOR2962MT0lJgYJFr+24latHYJ+At+M2pTW9uuM38Ks3RoVHB4ABbOnhLwX
// rQIDAQAB
// -----END PUBLIC KEY-----
// </pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>environment</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Environment { creator = Jinaga.User, environmentId = test }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>creator</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Jinaga.User</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>publicKey</td><td><div class="dni-plaintext"><pre>-----BEGIN PUBLIC KEY-----
// MIIBCgKCAQEAoCTbrASql8xsTby30NwsizfdDVrfg+8B6y/4brCoyjbGMRpQgh+a
// iDvcbNUsafgAyeUgxqOcpXmdyeHL3A4z0KjI1Ti5Us6RADSqve7yt21WZXxpGcmr
// YMlxwCJ5vmaxGN4DYAmWhZI7+4zZ6wBj+JarM8kEOz+H3RMsnp05qAoLmx9an+pg
// QT8X7pBc24b+uS9sAHl/hboQ/Rd7ivmErbvlyZiXktj8epuETM7VVn4aPMQqezT9
// NCQA6kHRC49pTrv9qtGPhI6JXIODG/blMPG6WtNY+7zjEOYAtKf6isq53r1d0hVa
// HbdDnPpLQmoqY6/xi17nMRsX3GrVdt7AgQIDAQAB
// -----END PUBLIC KEY-----
// </pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>environmentId</td><td><div class="dni-plaintext"><pre>test</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>createdAt</td><td><span>2024-05-31 16:02:18Z</span></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %%
var servicePrincipalsInEnvironment = Given<Environment>.Match((environment, facts) =>
    from servicePrincipal in facts.OfType<ServicePrincipal>()
    where servicePrincipal.environment == environment &&
        !facts.OfType<RevokeServicePrincipal>().Any(revoke => revoke.servicePrincipal == servicePrincipal)
    select servicePrincipal
);

var servicePrincipals = await jinagaClient.Query(servicePrincipalsInEnvironment, environment);

jinagaClient.RenderFacts(servicePrincipals)
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 11.0.0 (20240428.1522)
//  -->
// <!-- Pages: 1 -->
// <svg width="439pt" height="271pt"
//  viewBox="0.00 0.00 439.00 271.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 267)">
// <polygon fill="white" stroke="none" points="-4,4 -4,-267 435,-267 435,4 -4,4"/>
// <!-- JYIJkjp124uJ2LkcwrustrWWchH8uBcButv/t2zu2YM9YGIAQliFKfZVAb4f1fdJnzjCqfm+uKJ253OLEIbymg== -->
// <g id="node1" class="node">
// <title>JYIJkjp124uJ2LkcwrustrWWchH8uBcButv/t2zu2YM9YGIAQliFKfZVAb4f1fdJnzjCqfm+uKJ253OLEIbymg==</title>
// <polygon fill="none" stroke="black" points="8,-132.5 8,-154.5 224,-154.5 224,-132.5 8,-132.5"/>
// <text text-anchor="start" x="84.12" y="-138.2" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// <polygon fill="none" stroke="black" points="8,-110.5 8,-132.5 70,-132.5 70,-110.5 8,-110.5"/>
// <text text-anchor="start" x="10.88" y="-116.2" font-family="Times,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="70,-110.5 70,-132.5 224,-132.5 224,-110.5 70,-110.5"/>
// <text text-anchor="start" x="72.75" y="-116.2" font-family="Times,serif" font-size="14.00">&#45;&#45;&#45;&#45;&#45;BEGIN PUBLIC KE...</text>
// </g>
// <!-- J7p3FGxhTGDeqgniTLY/pD8tK5jcSltkPSU1c3RMaDIFNIadVuH28O2J3rGc3m3jw2t1aNQTgOMDYbPJwVlfhQ== -->
// <g id="node2" class="node">
// <title>J7p3FGxhTGDeqgniTLY/pD8tK5jcSltkPSU1c3RMaDIFNIadVuH28O2J3rGc3m3jw2t1aNQTgOMDYbPJwVlfhQ==</title>
// <polygon fill="none" stroke="black" points="207,-237 207,-259 423,-259 423,-237 207,-237"/>
// <text text-anchor="start" x="283.12" y="-242.7" font-family="Times,serif" font-size="14.00">Jinaga.User</text>
// <polygon fill="none" stroke="black" points="207,-215 207,-237 269,-237 269,-215 207,-215"/>
// <text text-anchor="start" x="209.88" y="-220.7" font-family="Times,serif" font-size="14.00">publicKey</text>
// <polygon fill="none" stroke="black" points="269,-215 269,-237 423,-237 423,-215 269,-215"/>
// <text text-anchor="start" x="271.75" y="-220.7" font-family="Times,serif" font-size="14.00">&#45;&#45;&#45;&#45;&#45;BEGIN PUBLIC KE...</text>
// </g>
// <!-- 5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg== -->
// <g id="node3" class="node">
// <title>5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg==</title>
// <polygon fill="none" stroke="black" points="258,-132.5 258,-154.5 372,-154.5 372,-132.5 258,-132.5"/>
// <text text-anchor="start" x="261" y="-138.2" font-family="Times,serif" font-size="14.00">Azure.Environment</text>
// <polygon fill="none" stroke="black" points="258,-110.5 258,-132.5 346,-132.5 346,-110.5 258,-110.5"/>
// <text text-anchor="start" x="261.88" y="-116.2" font-family="Times,serif" font-size="14.00">environmentId</text>
// <polygon fill="none" stroke="black" points="346,-110.5 346,-132.5 372,-132.5 372,-110.5 346,-110.5"/>
// <text text-anchor="start" x="349.62" y="-116.2" font-family="Times,serif" font-size="14.00">test</text>
// </g>
// <!-- 5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg==&#45;&gt;J7p3FGxhTGDeqgniTLY/pD8tK5jcSltkPSU1c3RMaDIFNIadVuH28O2J3rGc3m3jw2t1aNQTgOMDYbPJwVlfhQ== -->
// <g id="edge1" class="edge">
// <title>5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg==&#45;&gt;J7p3FGxhTGDeqgniTLY/pD8tK5jcSltkPSU1c3RMaDIFNIadVuH28O2J3rGc3m3jw2t1aNQTgOMDYbPJwVlfhQ==</title>
// <path fill="none" stroke="black" d="M315,-158.31C315,-170.69 315,-185.89 315,-199.56"/>
// <polygon fill="black" stroke="black" points="311.5,-199.55 315,-209.55 318.5,-199.55 311.5,-199.55"/>
// <text text-anchor="middle" x="335.62" y="-179.7" font-family="Times,serif" font-size="14.00"> creator</text>
// </g>
// <!-- YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ== -->
// <g id="node4" class="node">
// <title>YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ==</title>
// <polygon fill="none" stroke="black" points="79,-27 79,-49 277,-49 277,-27 79,-27"/>
// <text text-anchor="start" x="115" y="-32.7" font-family="Times,serif" font-size="14.00">Azure.ServicePrincipal</text>
// <polygon fill="none" stroke="black" points="79,-5 79,-27 137,-27 137,-5 79,-5"/>
// <text text-anchor="start" x="81.75" y="-10.7" font-family="Times,serif" font-size="14.00">createdAt</text>
// <polygon fill="none" stroke="black" points="137,-5 137,-27 277,-27 277,-5 137,-5"/>
// <text text-anchor="start" x="139.88" y="-10.7" font-family="Times,serif" font-size="14.00">2024&#45;05&#45;31T16:02:18....</text>
// <polygon fill="none" stroke="black" points="78,-4 78,-50 278,-50 278,-4 78,-4"/>
// </g>
// <!-- YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ==&#45;&gt;JYIJkjp124uJ2LkcwrustrWWchH8uBcButv/t2zu2YM9YGIAQliFKfZVAb4f1fdJnzjCqfm+uKJ253OLEIbymg== -->
// <g id="edge2" class="edge">
// <title>YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ==&#45;&gt;JYIJkjp124uJ2LkcwrustrWWchH8uBcButv/t2zu2YM9YGIAQliFKfZVAb4f1fdJnzjCqfm+uKJ253OLEIbymg==</title>
// <path fill="none" stroke="black" d="M162.51,-53.85C154.72,-66.86 145.17,-82.81 136.75,-96.86"/>
// <polygon fill="black" stroke="black" points="133.78,-95.02 131.64,-105.39 139.78,-98.61 133.78,-95.02"/>
// <text text-anchor="middle" x="163.12" y="-75.2" font-family="Times,serif" font-size="14.00"> user</text>
// </g>
// <!-- YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ==&#45;&gt;5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg== -->
// <g id="edge3" class="edge">
// <title>YO0QT/MY+ffQjwau0MH81M8jOJVm9A3c8R5xd8zt4jP+UsyS2nLbTsn/hSNpohOUSN/3tfxpXRP4IntWuSjwdQ==&#45;&gt;5zH07bGoBwtv56nPl/RCiNlnxaV7f19FZq4J1TR6w1pCiUEBtwuViQop063L7t4CNpnIyXZ1tKZp4lfE/5teGg==</title>
// <path fill="none" stroke="black" d="M212.22,-53.85C230.69,-67.81 253.65,-85.15 273.17,-99.9"/>
// <polygon fill="black" stroke="black" points="270.87,-102.54 280.95,-105.78 275.09,-96.96 270.87,-102.54"/>
// <text text-anchor="middle" x="290.38" y="-75.2" font-family="Times,serif" font-size="14.00"> environment</text>
// </g>
// </g>
// </svg>

// %% [markdown]
// ## Subscriptions
//
// Azure informs the landing page app of subscription activities by and related to a user.
// It does so through webhook calls.
// The landing page app also permits that user to take actions on the subscription through its own user interface.

// %%
[FactType("Azure.Subscription")]
public record Subscription(Environment environment, Guid subscriptionId);

[FactType("Azure.Subscription.Unsubscribe")]
public record Unsubscribe(Subscription subscription);

Renderer.RenderTypes(typeof(Subscription), typeof(Unsubscribe))

// %% [markdown]
// This model also represents the user by their identifier.
// The model does not treat Azure users as Jinaga users.
// It records information _about_ the user, not _by_ the user.
//
// A user can transfer a subscription to another user.
// This is modeled using the Entity Reference pattern, a kind of mutable property.

// %%
[FactType("Azure.UserIdentity")]
public record UserIdentity(Environment environment, string userId);

[FactType("Azure.Subscription.UserIdentity")]
public record SubscriptionUserIdentity(Subscription subscription, UserIdentity userIdentity, SubscriptionUserIdentity[] prior);

Renderer.RenderTypes(typeof(SubscriptionUserIdentity))

// %% [markdown]
// ## Subscription Activities
//
// A user can adjust the plan to which a subscription applies.
// They can also adjust the quantity of the plan.
// These are captured as mutable properties.

// %%
[FactType("Azure.Plan")]
public record Plan(Environment environment, string planId);

[FactType("Azure.SubscriptionPlan")]
public record SubscriptionPlan(Subscription subscription, Plan plan, SubscriptionPlan[] prior);

[FactType("Azure.SubscriptionQuantity")]
public record SubscriptionQuantity(Subscription subscription, int quantity, SubscriptionQuantity[] prior);

Renderer.RenderTypes(typeof(Plan), typeof(SubscriptionPlan), typeof(SubscriptionQuantity))

// %% [markdown]
// The user can activate and deactivate their subscription.
// Azure can also choose to suspend and reinstate the subscription.
// Finally, the user periodically renews their subscription.
// Renewal occurs within a monthly period.

// %%
[FactType("Azure.Subscription.Activate")]
public record Activate(Subscription subscription, DateTime activatedAt);

[FactType("Azure.Subscription.Deactivate")]
public record Deactivate(Activate activate, DateTime deactivatedAt);

[FactType("Azure.Subscription.Suspend")]
public record Suspend(Subscription subscription, DateTime suspendedAt);

[FactType("Azure.Subscription.Reinstate")]
public record Reinstate(Suspend suspend, DateTime reinstatedAt);

[FactType("Azure.Month")]
public record Month(Environment environment, int year, int month);

[FactType("Azure.Subscription.Renew")]
public record Renew(Subscription subscription, Month month, DateTime renewedAt);

Renderer.RenderTypes(typeof(Suspend), typeof(Reinstate), typeof(Renew), typeof(Activate), typeof(Deactivate))
